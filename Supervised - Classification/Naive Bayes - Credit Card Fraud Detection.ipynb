# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df=pd.read_csv('credit.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 31 columns):
# Time      1160 non-null int64
# V1        1160 non-null float64
# V2        1160 non-null float64
# V3        1160 non-null float64
# V4        1160 non-null float64
# V5        1160 non-null float64
# V6        1160 non-null float64
# V7        1160 non-null float64
# V8        1160 non-null float64
# V9        1160 non-null float64
# V10       1160 non-null float64
# V11       1160 non-null float64
# V12       1160 non-null float64
# V13       1160 non-null float64
# V14       1160 non-null float64
# V15       1160 non-null float64
# V16       1160 non-null float64
# V17       1160 non-null float64
# V18       1160 non-null float64
# V19       1160 non-null float64
# V20       1160 non-null float64
# V21       1160 non-null float64
# V22       1160 non-null float64
# V23       1160 non-null float64
# V24       1160 non-null float64
# V25       1160 non-null float64
# V26       1160 non-null float64
# V27       1160 non-null float64
# V28       1160 non-null float64
# Amount    1160 non-null float64
# Class     1160 non-null int64
# dtypes: float64(29), int64(2)
# memory usage: 281.0 KB

# %%
df.describe()
# Out:
#               Time           V1           V2           V3           V4  \
# count  1160.000000  1160.000000  1160.000000  1160.000000  1160.000000
# mean    434.431897    -0.196593     0.234403     0.877445     0.251854
# std     260.874028     1.335347     1.160484     1.015105     1.251554
# min       0.000000    -6.169664   -12.114213    -5.694973    -4.657545
# 25%     208.250000    -0.943640    -0.185256     0.301691    -0.456110
# 50%     432.500000    -0.378331     0.286005     0.869673     0.352908
# 75%     657.250000     1.122762     0.867528     1.518721     1.062827
# max     907.000000     1.685314     6.118940     4.017561     4.861129
#
#                 V5           V6           V7           V8           V9  ...  \
# count  1160.000000  1160.000000  1160.000000  1160.000000  1160.000000  ...
# mean     -0.032086     0.121443     0.102529    -0.070757     0.001378  ...
# std       1.072197     1.211304     0.830269     0.876887     0.920580  ...
# min      -6.631951    -3.498447    -4.925568    -7.494658    -2.980624  ...
# 25%      -0.551635    -0.643977    -0.322788    -0.185671    -0.490683  ...
# 50%      -0.148059    -0.132129     0.095951     0.022356    -0.069611  ...
# 75%       0.429187     0.473238     0.567248     0.247948     0.427535  ...
# max       7.672544     5.122103     4.808426     3.877662     6.450992  ...
#
#                V21          V22          V23          V24          V25  \
# count  1160.000000  1160.000000  1160.000000  1160.000000  1160.000000
# mean     -0.004723    -0.119103    -0.044596     0.005284     0.115913
# std       0.620088     0.608258     0.361608     0.611628     0.422199
# min      -4.134608    -2.776923    -4.020300    -1.867208    -1.544209
# 25%      -0.223532    -0.536532    -0.180812    -0.340357    -0.151441
# 50%      -0.079551    -0.094317    -0.051383     0.091783     0.146677
# 75%       0.083616     0.294863     0.071146     0.421694     0.419504
# max       5.273420     1.957759     3.150413     1.215279     1.206820
#
#                V26          V27          V28       Amount        Class
# count  1160.000000  1160.000000  1160.000000  1160.000000  1160.000000
# mean      0.028957     0.013669    -0.016196    65.936405     0.001724
# std       0.468315     0.342592     0.262889   182.691590     0.041505
# min      -1.243924    -3.525281    -2.735623     0.000000     0.000000
# 25%      -0.301853    -0.049834    -0.023003     5.402500     0.000000
# 50%      -0.000715     0.020955     0.020239    15.800000     0.000000
# 75%       0.268483     0.114097     0.083974    55.820000     0.000000
# max       3.087444     2.490503     1.575380  3828.040000     1.000000
#
# [8 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
non_fraud=df[df['Class']==0]

# %%
fraud=df[df['Class']==1]

# %%
non_fraud.shape
# Out:
# (1158, 31)

# %%
fraud.shape
# Out:
# (2, 31)

# %%
## Fraud percentage
print('Percentage Fraud',(len(fraud)/len(df))*100,'%') # 0.17 are fraud transactions
# Out:
# Percentage Fraud 0.1724137931034483 %

# %%
sns.countplot(df['Class'],label='Count')

# %%
plt.figure(figsize=(30,10))
sns.heatmap(df.corr(),annot=True)
